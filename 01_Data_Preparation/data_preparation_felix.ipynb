# %% [markdown]
# # Data Preparation

# %% [markdown]
# 1. Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ast

# %% [markdown]
# 2. Read in the csv-file

# %%
charging_data = pd.read_csv("charging_sessions.csv")

# %% [markdown]
# ## Data Dimensionality

# %% [markdown]
# Evaluate the dataset concerning dimensionality, data types and overall structure at first glance.

# %%
charging_data.info(show_counts=True)
charging_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66450 entries, 0 to 66449
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        66450 non-null  int64
#  1   id                66450 non-null  object
#  2   connectionTime    66450 non-null  object
#  3   disconnectTime    66450 non-null  object
#  4   doneChargingTime  62362 non-null  object
#  5   kWhDelivered      66450 non-null  float64
#  6   sessionID         66450 non-null  object
#  7   siteID            66450 non-null  int64
#  8   spaceID           66450 non-null  object
#  9   stationID         66450 non-null  object
#  10  timezone          66450 non-null  object
#  11  userID            49187 non-null  float64
#  12  userInputs        49187 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 6.6+ MB
#    Unnamed: 0                        id             connectionTime  \
# 0           0  5e23b149f9af8b5fe4b973cf  2020-01-02 13:08:54+00:00
# 1           1  5e23b149f9af8b5fe4b973d0  2020-01-02 13:36:50+00:00
# 2           2  5e23b149f9af8b5fe4b973d1  2020-01-02 13:56:35+00:00
# 3           3  5e23b149f9af8b5fe4b973d2  2020-01-02 13:59:58+00:00
# 4           4  5e23b149f9af8b5fe4b973d3  2020-01-02 14:00:01+00:00
#
#               disconnectTime           doneChargingTime  kWhDelivered  \
# 0  2020-01-02 19:11:15+00:00  2020-01-02 17:31:35+00:00        25.016
# 1  2020-01-02 22:38:21+00:00  2020-01-02 20:18:05+00:00        33.097
# 2  2020-01-03 00:39:22+00:00  2020-01-02 16:35:06+00:00         6.521
# 3  2020-01-02 16:38:39+00:00  2020-01-02 15:18:45+00:00         2.355
# 4  2020-01-02 22:08:40+00:00  2020-01-02 18:17:30+00:00        13.375
#
#                                 sessionID  siteID  spaceID    stationID  \
# 0  1_1_179_810_2020-01-02 13:08:53.870034       1  AG-3F30  1-1-179-810
# 1  1_1_193_825_2020-01-02 13:36:49.599853       1  AG-1F01  1-1-193-825
# 2  1_1_193_829_2020-01-02 13:56:35.214993       1  AG-1F03  1-1-193-829
# 3  1_1_193_820_2020-01-02 13:59:58.309319       1  AG-1F04  1-1-193-820
# 4  1_1_193_819_2020-01-02 14:00:00.779967       1  AG-1F06  1-1-193-819
#
#               timezone  userID  \
# 0  America/Los_Angeles   194.0
# 1  America/Los_Angeles  4275.0
# 2  America/Los_Angeles   344.0
# 3  America/Los_Angeles  1117.0
# 4  America/Los_Angeles   334.0
#
#                                           userInputs
# 0  [{'WhPerMile': 250, 'kWhRequested': 25.0, 'mil...
# 1  [{'WhPerMile': 280, 'kWhRequested': 70.0, 'mil...
# 2  [{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 3  [{'WhPerMile': 400, 'kWhRequested': 8.0, 'mile...
# 4  [{'WhPerMile': 400, 'kWhRequested': 16.0, 'mil...

# %% [markdown]
# ## Date Conversions

# %% [markdown]
# Every datetime entry is originally in UTC. To analyze the data in local time, we need to convert these values to the timezone of each charging site.

# %%
date_columns = ["connectionTime", "disconnectTime", "doneChargingTime"]

for data in date_columns:
    charging_data[data] = pd.to_datetime(charging_data[data])

def convert_to_local(row): 
    tz = row["timezone"]
    for col in date_columns:
        ts = row[col]
        if pd.isna(ts):
            continue 
        row[col] = ts.tz_convert(tz)
    return row 

charging_data = charging_data.apply(convert_to_local, axis=1)

charging_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66450 entries, 0 to 66449
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        66450 non-null  int64
#  1   id                66450 non-null  object
#  2   connectionTime    66450 non-null  datetime64[ns, America/Los_Angeles]
#  3   disconnectTime    66450 non-null  datetime64[ns, America/Los_Angeles]
#  4   doneChargingTime  62362 non-null  datetime64[ns, America/Los_Angeles]
#  5   kWhDelivered      66450 non-null  float64
#  6   sessionID         66450 non-null  object
#  7   siteID            66450 non-null  int64
#  8   spaceID           66450 non-null  object
#  9   stationID         66450 non-null  object
#  10  timezone          66450 non-null  object
#  11  userID            49187 non-null  float64
#  12  userInputs        49187 non-null  object
# dtypes: datetime64[ns, America/Los_Angeles](3), float64(2), int64(2), object(6)
# memory usage: 6.6+ MB

# %% [markdown]
# ## Handle User Inputs

# %% [markdown]
# There are three possible scenarios for userInputs:
# 1. No user inputs
# 2. Exactly one user input
# 3. Several user inputs
#
# Possible solutions for handling the userInputs: **TBD**
# - Leave the userInput attributes in the list column
# - Create one column per userInputs attribute --> Each column contains a list of the input attribute values
# - Create one column per userInputs attribute --> Each column contains only the last value for the input attribute

# %%
# Example of no userInputs 
print("No user inputs: \n", charging_data[charging_data["userInputs"].isnull()]["userInputs"].iloc[0])

# Example of one userInputs
print("Single user input: \n", charging_data["userInputs"].iloc[0])

# Example of multiple userInputs 
print("Multiple user inputs: \n", charging_data[charging_data["userID"] == 1117]["userInputs"].iloc[0])
# Out:
# No user inputs:
#  nan
# Single user input:
#  [{'WhPerMile': 250, 'kWhRequested': 25.0, 'milesRequested': 100, 'minutesAvailable': 463, 'modifiedAt': 'Thu, 02 Jan 2020 13:09:39 GMT', 'paymentRequired': True, 'requestedDeparture': 'Thu, 02 Jan 2020 20:51:54 GMT', 'userID': 194}]
# Multiple user inputs:
#  [{'WhPerMile': 400, 'kWhRequested': 8.0, 'milesRequested': 20, 'minutesAvailable': 65, 'modifiedAt': 'Thu, 02 Jan 2020 14:00:03 GMT', 'paymentRequired': True, 'requestedDeparture': 'Thu, 02 Jan 2020 15:04:58 GMT', 'userID': 1117}, {'WhPerMile': 400, 'kWhRequested': 8.0, 'milesRequested': 20, 'minutesAvailable': 65, 'modifiedAt': 'Thu, 02 Jan 2020 14:00:19 GMT', 'paymentRequired': True, 'requestedDeparture': 'Thu, 02 Jan 2020 15:04:58 GMT', 'userID': 1117}]

# %% [markdown]
# ## Duplicate Values

# %% [markdown]
# Check if "id" values are unique

# %%
duplicate_ids = charging_data["id"].duplicated(keep="first")
duplicate_ids = len(duplicate_ids[duplicate_ids == True])
duplicate_ids
# Out:
# 1413

# %% [markdown]
# Hence, there are 1413 duplicate IDs. Further inspection of the duplicates is required before determining how to handle them.

# %%
# Collect all duplicated IDs
duplicated_ids = charging_data[charging_data["id"].duplicated()]
duplicated_ids = duplicated_ids["id"].unique()

# Define the subset of variables to inspect for duplicates. Exclude the unnamed index column.
subset_cols = charging_data.columns.difference(["Unnamed: 0"])

duplicates = charging_data[charging_data.duplicated(subset=subset_cols)]
len(duplicates)
# Out:
# 1413

# %% [markdown]
# This shows that the entries with duplicate IDs also contain duplicate values for all other columns. Hence, the duplicates can be deleted without loss of information.

# %%
charging_data = charging_data.drop_duplicates(subset=subset_cols, keep="first")
charging_data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65037 entries, 0 to 65036
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        65037 non-null  int64
#  1   id                65037 non-null  object
#  2   connectionTime    65037 non-null  datetime64[ns, America/Los_Angeles]
#  3   disconnectTime    65037 non-null  datetime64[ns, America/Los_Angeles]
#  4   doneChargingTime  60950 non-null  datetime64[ns, America/Los_Angeles]
#  5   kWhDelivered      65037 non-null  float64
#  6   sessionID         65037 non-null  object
#  7   siteID            65037 non-null  int64
#  8   spaceID           65037 non-null  object
#  9   stationID         65037 non-null  object
#  10  timezone          65037 non-null  object
#  11  userID            47822 non-null  float64
#  12  userInputs        47822 non-null  object
# dtypes: datetime64[ns, America/Los_Angeles](3), float64(2), int64(2), object(6)
# memory usage: 6.9+ MB

# %% [markdown]
# ### Redundant features

# %% [markdown]
# We can drop the feature "Unnamed: 0". Furthermore the features "spaceID" and "stationID" hold the same information, as each spaceID belongs to exactly one stationID. Therefore we can also drop one of these features.

# %%
print("Unique values of spaceID: "+str(charging_data["spaceID"].nunique()))
print("Unique values of stationID: "+str(charging_data["stationID"].nunique()))
print((charging_data.groupby("spaceID")["stationID"].nunique() == 1).all())

charging_data = charging_data.drop(["Unnamed: 0", "stationID"], axis=1)
charging_data.info(show_counts=True)
# Out:
# Unique values of spaceID: 107
# Unique values of stationID: 107
# True
# <class 'pandas.core.frame.DataFrame'>
# Index: 65037 entries, 0 to 65036
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                65037 non-null  object
#  1   connectionTime    65037 non-null  datetime64[ns, America/Los_Angeles]
#  2   disconnectTime    65037 non-null  datetime64[ns, America/Los_Angeles]
#  3   doneChargingTime  60950 non-null  datetime64[ns, America/Los_Angeles]
#  4   kWhDelivered      65037 non-null  float64
#  5   sessionID         65037 non-null  object
#  6   siteID            65037 non-null  int64
#  7   spaceID           65037 non-null  object
#  8   timezone          65037 non-null  object
#  9   userID            47822 non-null  float64
#  10  userInputs        47822 non-null  object
# dtypes: datetime64[ns, America/Los_Angeles](3), float64(2), int64(1), object(5)
# memory usage: 6.0+ MB

# %% [markdown]
# ## Invalid Values

# %% [markdown]
# Possible invalid scenarios are:
#
# 1. connectionTime is after disconnectTime
# 2. connectionTime is after doneChargingTime
# 3. The same stationID has overlapping sessions
# 4. doneChargingTime is after disconnectTime

# %% [markdown]
# 1. Scenario

# %%
scenario1 = charging_data["connectionTime"] > charging_data["disconnectTime"]
scenario1.value_counts()
# Out:
# False    65037
# Name: count, dtype: int64

# %% [markdown]
# No invalid data found.

# %% [markdown]
# 2. Scenario

# %%
scenario2 = charging_data["connectionTime"] > charging_data["doneChargingTime"]
scenario2.value_counts()
# Out:
# False    65010
# True        27
# Name: count, dtype: int64

# %% [markdown]
# Invalid data found. It is physically not possible that the "doneChargingTime" is before the "connectionTime" so we delete these entires.

# %%
charging_data.drop(charging_data[charging_data["connectionTime"] > charging_data["doneChargingTime"]].index, inplace = True)

# %% [markdown]
# 3. Scenario

# %%
charging_data["next_connection"] = charging_data.groupby("spaceID")["connectionTime"].shift(-1)
charging_data["next_disconnect"] = charging_data.groupby("spaceID")["disconnectTime"].shift(-1)

charging_data["overlap"] = charging_data["disconnectTime"] > charging_data["next_connection"]
charging_data["overlap"].value_counts()
# Out:
# overlap
# False    64810
# True       200
# Name: count, dtype: int64

# %% [markdown]
# Invalid data found. It is also physically not possible that the same Space has two overlapping sessions so we delete these entries as well as the new created column "overlap".

# %%
charging_data.drop(charging_data[charging_data["overlap"]].index, inplace=True)

charging_data.drop(columns="overlap", inplace=True)

charging_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64810 entries, 0 to 65036
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                64810 non-null  object
#  1   connectionTime    64810 non-null  datetime64[ns, America/Los_Angeles]
#  2   disconnectTime    64810 non-null  datetime64[ns, America/Los_Angeles]
#  3   doneChargingTime  60729 non-null  datetime64[ns, America/Los_Angeles]
#  4   kWhDelivered      64810 non-null  float64
#  5   sessionID         64810 non-null  object
#  6   siteID            64810 non-null  int64
#  7   spaceID           64810 non-null  object
#  8   timezone          64810 non-null  object
#  9   userID            47635 non-null  float64
#  10  userInputs        47635 non-null  object
#  11  next_connection   64703 non-null  datetime64[ns, America/Los_Angeles]
#  12  next_disconnect   64703 non-null  datetime64[ns, America/Los_Angeles]
# dtypes: datetime64[ns, America/Los_Angeles](5), float64(2), int64(1), object(5)
# memory usage: 6.9+ MB

# %% [markdown]
# 4. scenario

# %%
scenario4 = charging_data["doneChargingTime"] > charging_data["disconnectTime"]
scenario4.value_counts()
# Out:
# False    60424
# True      4386
# Name: count, dtype: int64

# %% [markdown]
# Invalid data found. Since doneChargingTime cannot be after disconnectTime, we set doneChargingTime = disconnectTime for those cases.

# %%
charging_data.loc[scenario4, "doneChargingTime"] = charging_data.loc[scenario4, "disconnectTime"]

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Check for any missing values within the dataset

# %%
missing_values = charging_data.isnull().sum()
missing_values
# Out:
# id                      0
# connectionTime          0
# disconnectTime          0
# doneChargingTime     4081
# kWhDelivered            0
# sessionID               0
# siteID                  0
# spaceID                 0
# timezone                0
# userID              17175
# userInputs          17175
# next_connection       107
# next_disconnect       107
# dtype: int64

# %% [markdown]
# Quick analysis of the missing values:
# - **"userID"** and **"userInputs"**: Contain missing values as expected, since users are not required to register
# - **"doneChargingTime"**: Missing values are expected to be data irregularities and have to be dealt with in order to ensure a high data quality

# %% [markdown]
# Subsets of the data are created, to differentiate between regular and irregular (missing "doneChargingTime" value)

# %%
charging_data_regular_trips = charging_data[charging_data['doneChargingTime'].notnull()].copy()
charging_data_wo_doneChargingTime = charging_data[charging_data['doneChargingTime'].isnull()].copy()

print(f"Regular trips: {charging_data_regular_trips.shape[0]}")
print(f"Irregular trips without doneChargingTime value: {charging_data_wo_doneChargingTime.shape[0]}")
# Out:
# Regular trips: 60729
# Irregular trips without doneChargingTime value: 4081

# %% [markdown]
# **Extrapolate Missing 'doneChargingTime' Values**

# %% [markdown]
# Missing values are determined as follows:
# 1. Calculate average charging time per kWh
# 2. Estimate missing 'doneChargingTime' values using the existing 'kWhDelivered' variable and the calculated charging time per kWh
# 3. If estimated 'doneChargingTime' value is later than 'disconnectTime', then set 'doneChargingTime' = 'disconnectTime'

# %% [markdown]
# 1. Calculate average charging time per kWh (over all regular trips)

# %%
charging_data_regular_trips['parkDuration'] = charging_data_regular_trips['disconnectTime'] - charging_data_regular_trips['connectionTime']
charging_data_regular_trips['chargingDuration'] = charging_data_regular_trips['doneChargingTime'] - charging_data_regular_trips['connectionTime']
charging_data_regular_trips['minPerKWh'] = (charging_data_regular_trips['chargingDuration'].dt.total_seconds()/60).round() / charging_data_regular_trips['kWhDelivered']

avg_minPerKWh = charging_data_regular_trips['minPerKWh'].mean()
print(f"Average min per kWh: {avg_minPerKWh}")
# Out:
# Average min per kWh: 30.553951059846465

# %% [markdown]
# Evaluate whether kWhDelivered and chargingTime are linearly dependent

# %%
plt.hist(charging_data_regular_trips['minPerKWh'], bins=2000)
plt.xlim(left=0, right=200)
plt.show()

plt.scatter(x= charging_data_regular_trips['kWhDelivered'], y=charging_data_regular_trips['minPerKWh'])
plt.xlabel("kWh delivered")
plt.ylabel("charging duration in minutes per kWh")
plt.xlim(left=0, right=100)
plt.ylim(bottom=0, top=500)
plt.show()

# %% [markdown]
# The charging duration in minutes per kWh seem to be much higher when kWh delivered is smaller, so I would not calculate the missing doneChargingTimes by taking the mean of the existing doneChargingTime/ kWhDelivered.

# %%
charging_data_wo_doneChargingTime['doneChargingTime'] = (charging_data_wo_doneChargingTime['connectionTime'] + pd.to_timedelta(avg_timePerKWh.total_seconds() * charging_data_wo_doneChargingTime['kWhDelivered'], unit='s')).dt.round('s')
charging_data_wo_doneChargingTime.head()
# Out:
#                             id            connectionTime  \
# 3756  5ea3848df9af8b428bf97225 2020-04-08 09:36:53-07:00
# 3757  5ea4d60df9af8b46573f1ee7 2020-04-09 06:23:52-07:00
# 3758  5ea4d60df9af8b46573f1ee8 2020-04-09 06:40:03-07:00
# 3759  5ea4d60df9af8b46573f1ee9 2020-04-09 07:01:53-07:00
# 3760  5ea4d60df9af8b46573f1eea 2020-04-09 08:01:06-07:00
#
#                 disconnectTime          doneChargingTime  kWhDelivered  \
# 3756 2020-04-08 20:43:29-07:00 2020-04-08 17:16:57-07:00        25.183
# 3757 2020-04-09 10:59:02-07:00 2020-04-09 10:42:07-07:00        14.136
# 3758 2020-04-09 14:43:22-07:00 2020-04-09 10:59:31-07:00        14.203
# 3759 2020-04-09 09:33:40-07:00 2020-04-09 11:00:08-07:00        13.041
# 3760 2020-04-09 16:38:08-07:00 2020-04-09 09:47:00-07:00         5.797
#
#                                    sessionID  siteID  spaceID  \
# 3756  1_1_194_822_2020-04-08 16:36:53.316264       1  AG-1F12
# 3757  1_1_193_827_2020-04-09 13:23:51.689520       1  AG-1F02
# 3758  1_1_178_823_2020-04-09 13:39:55.115497       1  AG-1F08
# 3759  1_1_178_828_2020-04-09 14:01:53.467693       1  AG-1F10
# 3760  1_1_193_820_2020-04-09 15:01:06.343454       1  AG-1F04
#
#                  timezone  userID  \
# 3756  America/Los_Angeles   507.0
# 3757  America/Los_Angeles   419.0
# 3758  America/Los_Angeles  5065.0
# 3759  America/Los_Angeles   651.0
# 3760  America/Los_Angeles   466.0
#
#                                              userInputs  \
# 3756  [{'WhPerMile': 250, 'kWhRequested': 75.0, 'mil...
# 3757  [{'WhPerMile': 400, 'kWhRequested': 40.0, 'mil...
# 3758  [{'WhPerMile': 400, 'kWhRequested': 24.0, 'mil...
# 3759  [{'WhPerMile': 400, 'kWhRequested': 20.0, 'mil...
# 3760  [{'WhPerMile': 300, 'kWhRequested': 6.0, 'mile...
#
#                next_connection           next_disconnect
# 3756 2020-04-09 12:58:23-07:00 2020-04-09 18:59:05-07:00
# 3757 2020-04-13 06:29:10-07:00 2020-04-13 15:21:06-07:00
# 3758 2020-04-12 07:10:47-07:00 2020-04-12 18:16:53-07:00
# 3759 2020-04-10 06:17:59-07:00 2020-04-10 06:49:37-07:00
# 3760 2020-04-14 08:44:37-07:00 2020-04-14 12:10:47-07:00

# %% [markdown]
# As we cannot fix the invalid data, I would drop it.

# %%
charging_data = charging_data.dropna(subset=["doneChargingTime"])
charging_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60729 entries, 0 to 65036
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                60729 non-null  object
#  1   connectionTime    60729 non-null  datetime64[ns, America/Los_Angeles]
#  2   disconnectTime    60729 non-null  datetime64[ns, America/Los_Angeles]
#  3   doneChargingTime  60729 non-null  datetime64[ns, America/Los_Angeles]
#  4   kWhDelivered      60729 non-null  float64
#  5   sessionID         60729 non-null  object
#  6   siteID            60729 non-null  int64
#  7   spaceID           60729 non-null  object
#  8   timezone          60729 non-null  object
#  9   userID            44462 non-null  float64
#  10  userInputs        44462 non-null  object
#  11  next_connection   60629 non-null  datetime64[ns, America/Los_Angeles]
#  12  next_disconnect   60629 non-null  datetime64[ns, America/Los_Angeles]
# dtypes: datetime64[ns, America/Los_Angeles](5), float64(2), int64(1), object(5)
# memory usage: 6.5+ MB

# %% [markdown]
# ### Save the data as a csv

# %%
charging_data.to_csv("charging_data.csv")
